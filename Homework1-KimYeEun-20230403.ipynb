# %%
#2
print('              YYY  YYY                 YY   ')
print("            YYY      YYY               YY   ")
print("          YYY          YYY         YY  YY   ")
print("        YYY              YYY       YY  YY   ")
print("      YYY                  YYY     YY  YY   ")
print("    YYY                    YYY  YYYYY  YY   ")
print("    YYY                    YYY  YYYYY  YY   ")
print("    YYY                    YYY  YYYYY  YY   ")
print("    YYY                    YYY     YY  YY   ")
print("    YYY                    YYY     YY  YY   ")
print("    YYY                    YYY     YY  YY   ")
print("    YYY                    YYY  YYYYY  YY   ")
print("    YYY                    YYY  YYYYY  YY   ")
print("    YYY                    YYY  YYYYY  YY   ")
print("      YYY                YYY       YY  YY   ")
print("        YYY           YYY          YY  YY   ")
print("         YYY         YYY           YY  YY   ")
print("           YYY     YYY                 YY   ")
print("             YYY YYY                   YY   ")
# Out:
#               YYY  YYY                 YY
#             YYY      YYY               YY
#           YYY          YYY         YY  YY
#         YYY              YYY       YY  YY
#       YYY                  YYY     YY  YY
#     YYY                    YYY  YYYYY  YY
#     YYY                    YYY  YYYYY  YY
#     YYY                    YYY  YYYYY  YY
#     YYY                    YYY     YY  YY
#     YYY                    YYY     YY  YY
#     YYY                    YYY     YY  YY
#     YYY                    YYY  YYYYY  YY
#     YYY                    YYY  YYYYY  YY
#     YYY                    YYY  YYYYY  YY
#       YYY                YYY       YY  YY
#         YYY           YYY          YY  YY
#          YYY         YYY           YY  YY
#            YYY     YYY                 YY
#              YYY YYY                   YY

# %%
#3
import random
import numpy as np

x = 0
sum = 0 

for i in range(100):
    for N in range(1000000):
        N = np.random.randint(0,9)
        num = str(N)
        if "021240" in num:
            x = x + 1 
            i = i + 1
        else:
            i = i + 1
            
sum += x
Total= (sum/100)*100
print(Total,"%")
# Out:
# 0.0 %

# %%
#4
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv("https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
mhv = data['median_house_value']
mi = data['median_income']
plt.figure(figsize = (10,10))
plt.xlabel('median_house_value', fontsize = 10)
plt.ylabel('median_income', fontsize = 10)
plt.scatter(mhv, mi)

# %%
lon = data['longitude']
lat = data['latitude']
mhv = data['median_house_value']

plt.figure(figsize = (8,8))
plt.xlabel('latitude', fontsize = 10)
plt.ylabel('longitude', fontsize = 10)
plt.scatter(lat, lon, c = mhv, cmap ='jet')

# %%
#5
import numpy as np
rowsize =2
colsize = 8

c=np.zeros((rowsize, colsize))

c[0][0]=1
c[0][1]=9
c[0][2]=9
c[0][3]=8
c[0][4]=0
c[0][5]=2
c[0][6]=1
c[0][7]=2

c[1][0]=2
c[1][1]=0
c[1][2]=2
c[1][3]=2
c[1][4]=0
c[1][5]=2
c[1][6]=1
c[1][7]=2

print(c)

#a. Do c+7, c-7, c*7, c+c, c/c. 

print(c+7)
print(c-7)
print(np.multiply(c,7))
print(c+c)
print(c/c)

#b. Do c∙c. Do c∙c^T. Do c^T∙c
print(np.multiply(c,c))
print(np.dot(c,np.transpose(c)))
print(np.dot(np.transpose(c),c))

#b.when dot product the transposed matrices, Do c∙c. Do c∙c^T. Do c^T∙c
print(np.multiply(c,c))
print(np.dot(c,np.transpose(c)))
print(np.dot(np.transpose(c),c))
# Out:
# [[1. 9. 9. 8. 0. 2. 1. 2.]
#  [2. 0. 2. 2. 0. 2. 1. 2.]]
# [[ 8. 16. 16. 15.  7.  9.  8.  9.]
#  [ 9.  7.  9.  9.  7.  9.  8.  9.]]
# [[-6.  2.  2.  1. -7. -5. -6. -5.]
#  [-5. -7. -5. -5. -7. -5. -6. -5.]]
# [[ 7. 63. 63. 56.  0. 14.  7. 14.]
#  [14.  0. 14. 14.  0. 14.  7. 14.]]
# [[ 2. 18. 18. 16.  0.  4.  2.  4.]
#  [ 4.  0.  4.  4.  0.  4.  2.  4.]]
# [[ 1.  1.  1.  1. nan  1.  1.  1.]
#  [ 1. nan  1.  1. nan  1.  1.  1.]]
# [[ 1. 81. 81. 64.  0.  4.  1.  4.]
#  [ 4.  0.  4.  4.  0.  4.  1.  4.]]
# [[236.  45.]
#  [ 45.  21.]]
# [[ 5.  9. 13. 12.  0.  6.  3.  6.]
#  [ 9. 81. 81. 72.  0. 18.  9. 18.]
#  [13. 81. 85. 76.  0. 22. 11. 22.]
#  [12. 72. 76. 68.  0. 20. 10. 20.]
#  [ 0.  0.  0.  0.  0.  0.  0.  0.]
#  [ 6. 18. 22. 20.  0.  8.  4.  8.]
#  [ 3.  9. 11. 10.  0.  4.  2.  4.]
#  [ 6. 18. 22. 20.  0.  8.  4.  8.]]
# [[ 1. 81. 81. 64.  0.  4.  1.  4.]
#  [ 4.  0.  4.  4.  0.  4.  1.  4.]]
# [[236.  45.]
#  [ 45.  21.]]
# [[ 5.  9. 13. 12.  0.  6.  3.  6.]
# ...

# %%
#6
import matplotlib.pyplot as plt
# %matplotlib inline

class Student:
    def __init__(self,age,gender,score):
        self.age = age
        self.gender = gender
        self.score = score
    
    def educlev(self): 
        if self.age < 8:
            print("Preschool")
        elif self.age > 7 and self.age < 14:
            print("Elementary school student")
        elif self.age > 13 and self.age < 17:
            print("Middle school student")
        elif self.age > 16 and self.age < 20:
            print("High school student")
        else:
            print("Undergrad")
        
    def grades(self):
        if self.score > 94:
            print("A+")
        elif self.score > 89:
            print("A")
        elif self.score > 84:
            print("B+")
        elif self.score > 79:
            print("B")
        elif self.score > 74:
            print("C+")
        elif self.score > 69:
            print("C")
        elif self.score > 64:
            print("D+")
        elif self.score > 59:
            print("D")
        else:
            print('F')

    
    def definegen(self):
        if self.gender == "M" or self.gender == 'm':
            print("Male")
        elif self.gender == "F" or self.gender == 'f':
            print("Female")
        else:
            print("Non-binary")
        
        
#Example            
#1)
Steven = Student(7, "M", 88.4)
Steven.educlev()
Steven.grades()
Steven.definegen()

#2)
Julie = Student(15, "F", 73)
Julie.educlev()
Julie.grades()
Julie.definegen()

#3)
Kim = Student(19, "n", 91)
Kim.educlev()
Kim.grades()
Kim.definegen()
# Out:
# Preschool
# B+
# Male
# Middle school student
# C
# Female
# High school student
# A
# Non-binary
